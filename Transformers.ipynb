# %%
! pip install transformers
print('done')
! pip install transformers[sentencepiece]
print('done')
! pip install sentencepiece
print('done')
! pip install gtts
print('done')
# Out:
# Requirement already satisfied: transformers in c:\users\abo0o\anaconda3\lib\site-packages (4.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (20.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (5.3.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (1.21.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (4.63.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (0.11.6)
# Requirement already satisfied: requests in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (0.0.47)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers) (2020.10.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abo0o\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\abo0o\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: six in c:\users\abo0o\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (1.16.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\abo0o\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: joblib in c:\users\abo0o\anaconda3\lib\site-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: click in c:\users\abo0o\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.4)
# done
# Requirement already satisfied: transformers[sentencepiece] in c:\users\abo0o\anaconda3\lib\site-packages (4.17.0)
# Requirement already satisfied: filelock in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (1.21.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (5.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (20.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (4.63.1)
# Requirement already satisfied: requests in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.4.0)
# doneRequirement already satisfied: regex!=2019.12.17 in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (2020.10.15)
# Requirement already satisfied: sacremoses in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.0.47)
# Requirement already satisfied: protobuf; extra == "sentencepiece" in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (3.14.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91; extra == "sentencepiece" in c:\users\abo0o\anaconda3\lib\site-packages (from transformers[sentencepiece]) (0.1.96)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\abo0o\anaconda3\lib\site-packages (from packaging>=20.0->transformers[sentencepiece]) (2.4.7)
# Requirement already satisfied: six in c:\users\abo0o\anaconda3\lib\site-packages (from packaging>=20.0->transformers[sentencepiece]) (1.16.0)
#
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\abo0o\anaconda3\lib\site-packages (from tqdm>=4.27->transformers[sentencepiece]) (0.4.4)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abo0o\anaconda3\lib\site-packages (from requests->transformers[sentencepiece]) (1.26.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abo0o\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers[sentencepiece]) (4.1.1)
# Requirement already satisfied: joblib in c:\users\abo0o\anaconda3\lib\site-packages (from sacremoses->transformers[sentencepiece]) (0.17.0)
# Requirement already satisfied: click in c:\users\abo0o\anaconda3\lib\site-packages (from sacremoses->transformers[sentencepiece]) (8.0.4)
# Requirement already satisfied: sentencepiece in c:\users\abo0o\anaconda3\lib\site-packages (0.1.96)
# done
# Requirement already satisfied: gtts in c:\users\abo0o\anaconda3\lib\site-packages (2.2.4)
# Requirement already satisfied: click in c:\users\abo0o\anaconda3\lib\site-packages (from gtts) (8.0.4)
# Requirement already satisfied: requests in c:\users\abo0o\anaconda3\lib\site-packages (from gtts) (2.27.1)
# Requirement already satisfied: six in c:\users\abo0o\anaconda3\lib\site-packages (from gtts) (1.16.0)done
#
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\abo0o\anaconda3\lib\site-packages (from click->gtts) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abo0o\anaconda3\lib\site-packages (from requests->gtts) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abo0o\anaconda3\lib\site-packages (from requests->gtts) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\abo0o\anaconda3\lib\site-packages (from requests->gtts) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\abo0o\anaconda3\lib\site-packages (from requests->gtts) (3.3)

# %%
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\transformers\file_utils.py in _get_module(self, module_name)
#    2776         try:
# -> 2777             return importlib.import_module("." + module_name, self.__name__)
#    2778         except Exception as e:
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\__init__.py in <module>
#      52 from .object_detection import ObjectDetectionPipeline
# ---> 53 from .question_answering import QuestionAnsweringArgumentHandler, QuestionAnsweringPipeline
#      54 from .table_question_answering import TableQuestionAnsweringArgumentHandler, TableQuestionAnsweringPipeline
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\question_answering.py in <module>
#       6
# ----> 7 from ..data import SquadExample, SquadFeatures, squad_convert_examples_to_features
#       8 from ..file_utils import PaddingStrategy, add_end_docstrings, is_tf_available, is_torch_available
#
# ~\anaconda3\lib\site-packages\transformers\data\__init__.py in <module>
#      29 )
# ---> 30 from .metrics import glue_compute_metrics, xnli_compute_metrics
#      31 from .processors import (
#
# ~\anaconda3\lib\site-packages\transformers\data\metrics\__init__.py in <module>
#      21
# ---> 22 if is_sklearn_available():
#      23     from sklearn.metrics import f1_score, matthews_corrcoef
#
# ~\anaconda3\lib\site-packages\transformers\file_utils.py in is_sklearn_available()
#     500         return False
# --> 501     return is_scipy_available() and importlib.util.find_spec("sklearn.metrics")
#     502
#
# ~\anaconda3\lib\importlib\util.py in find_spec(name, package)
#      93         if parent_name:
# ---> 94             parent = __import__(parent_name, fromlist=['__path__'])
#      95             try:
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      79     from . import __check_build  # noqa: F401
# ---> 80     from .base import clone
#      81     from .utils._show_versions import show_versions
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#
# ~\anaconda3\lib\site-packages\sklearn\utils\class_weight.py in <module>
#       6
# ----> 7 from .validation import _deprecate_positional_args
#       8
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in <module>
#      24
# ---> 25 from .fixes import _object_dtype_isnan, parse_version
#      26 from .. import get_config as _get_config
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in <module>
#      17 import scipy
# ---> 18 import scipy.stats
#      19 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#
# ~\anaconda3\lib\site-packages\scipy\stats\__init__.py in <module>
#     383
# --> 384 from .stats import *
#     385 from .distributions import *
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in <module>
#     184 from scipy import linalg
# --> 185 from . import distributions
#     186 from . import mstats_basic
#
# ~\anaconda3\lib\site-packages\scipy\stats\distributions.py in <module>
#       9
# ---> 10 from ._distn_infrastructure import (entropy, rv_discrete, rv_continuous,
#      11                                     rv_frozen)
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      24 # for root finding for discrete distribution ppf, and max likelihood estimation
# ---> 25 from scipy import optimize
#      26
#
# ~\anaconda3\lib\site-packages\scipy\optimize\__init__.py in <module>
#     389 from .optimize import *
# --> 390 from ._minimize import *
#     391 from ._root import *
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in <module>
#      33 from .lbfgsb import _minimize_lbfgsb
# ---> 34 from .tnc import _minimize_tnc
#      35 from .cobyla import _minimize_cobyla
#
# ~\anaconda3\lib\site-packages\scipy\optimize\tnc.py in <module>
#      36
# ---> 37 from scipy.optimize import moduleTNC, approx_fprime
#      38 from .optimize import MemoizeJac, OptimizeResult, _check_unknown_options
#
# ImportError: cannot import name 'moduleTNC' from partially initialized module 'scipy.optimize' (most likely due to a circular import) (C:\Users\abo0o\anaconda3\lib\site-packages\scipy\optimize\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-69a9fd07ccac> in <module>
# ----> 1 from transformers import pipeline
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\anaconda3\lib\site-packages\transformers\file_utils.py in __getattr__(self, name)
#    2765             value = self._get_module(name)
#    2766         elif name in self._class_to_module.keys():
# -> 2767             module = self._get_module(self._class_to_module[name])
#    2768             value = getattr(module, name)
#    2769         else:
#
# ~\anaconda3\lib\site-packages\transformers\file_utils.py in _get_module(self, module_name)
#    2777             return importlib.import_module("." + module_name, self.__name__)
#    2778         except Exception as e:
# -> 2779             raise RuntimeError(
#    2780                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its traceback):\n{e}"
#    2781             ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# cannot import name 'moduleTNC' from partially initialized module 'scipy.optimize' (most likely due to a circular import) (C:\Users\abo0o\anaconda3\lib\site-packages\scipy\optimize\__init__.py)

# %%
classifier = pipeline("automatic-speech-recognition",model='fractalego/personal-speech-to-text-model')
translation = pipeline('translation_XX_to_YY',model='Helsinki-NLP/opus-mt-en-ar')

# %%
#classifier.save_pretrained("./my_named_bert")

# %%
from google.colab import files
uploaded = files.upload()

# %%
file ="/content/One Minute English #1 - Learn Vocabulary Fast.mp3"
file1 = '/content/zain.mp3'
file2='/content/11.ogg'

# %%
speech2text = classifier(file1)
text= list(speech2text.values())
text2text = translation(text)
text2 =list(text2text[0].values())

print('English Translation is ',text)
print("Arabic translation is ",text2)

# %%
from gtts import gTTS
mytext =' '.join([str(elem) for elem in text2])
language = 'ar'
myobj = gTTS(text=mytext, lang=language, slow=False)
myobj.save("welcome.mp3")

# %%
from IPython.display import Audio
Audio("welcome.mp3")
